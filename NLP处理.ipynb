# %%
import pandas as pd
columns = ['title','source_0','content_0','author_0']
data_sample = pd.read_csv('./result/test.csv',names= columns,encoding='gbk')

# %%
data_sample
# Out:
#                                    title  \
# 0                    上能电气宁夏10GW逆变器工厂正式投产
# 1                      江苏晶飞5GW高效光伏产业项目落地
# 2                   北非最大！阳光电源签约埃及200MW项目
# 3        天津大沽街引进华电海晶“盐光互补”光伏发电项目，总投资40亿元
# 4   江西公布2021年首批光伏发电项目竞争结果，大唐、华能、国家能源位列前三
# 5      5月20日前报送！河南及甘肃相继启动源网荷储、多能互补项目申报工作
# 6        总投资8.7亿元！凯盛一期项目西部首条光伏玻璃生产线点火投产！
# 7    总投资4.1亿元！年产400套(1200片)风电叶片项目落户齐齐哈尔！
# 8                             “光伏公寓”，来了！
# 9           重大签约：中核汇能2GW滩涂光伏、中国电建智利480MW
# 10                浙江海宁启动全省首个用户侧“光伏+储能”项目
# 11         100MW/200MWh！湖南省最大电网侧储能电站城步开建
# 12                  中核拟在连云港投建2GW滩涂光伏示范项目
# 13       总投资214亿！青海海西4000兆瓦风光储氢一体化项目协议签约
# 14         214亿！中国能建签署青海海西4GW风光储氢一体化项目协议
# 15             国网公布2021年第六批可再生能源发电补贴项目清单
# 16           2021-2030年全球预计新增风电装机容量接近1太瓦
# 17             英国示范氢气燃料供热住宅，2030年前建立氢能小镇
# 18                      德国与加拿大计划联合开发绿色氢能
# 19        Saipem希望在意大利、阿尔巴尼亚和摩洛哥建立绿色氢生产厂
#
#                                             source_0  \
# ...

# %%
# 结巴包
import jieba

# %%
sample_title = data_sample.iloc[0,0]
sample_title
# Out:
# '上能电气宁夏10GW逆变器工厂正式投产'

# %%
seg_list = jieba.cut(sample_title, cut_all=False)
print("Default Mode: " + "/ ".join(seg_list))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\Chris\AppData\Local\Temp\jieba.cache
# Loading model cost 1.331 seconds.
# Prefix dict has been built succesfully.
# Default Mode: 上能/ 电气/ 宁夏/ 10GW/ 逆变器/ 工厂/ 正式/ 投产
